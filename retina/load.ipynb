# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd

COLOR_MODE = "rgb"
CHANNELS = 1 if COLOR_MODE == "grayscale" else 3
IMAGE_HEIGHT = 150
IMAGE_WIDTH = 150

TRAINING_PATH = "./retina_dataset/Training_Set/Training_Set"
TRAINING_PATH_CSV = f"{TRAINING_PATH}/RFMiD_Training_Labels.csv"

TESTING_PATH = "./retina_dataset/Test_Set/Test_Set"
TESTING_PATH_CSV = f"{TESTING_PATH}/RFMiD_Testing_Labels.csv"

VALIDATION_PATH = "./retina_dataset/Evaluation_Set/Evaluation_Set"
VALIDATION_PATH_CSV = f"{VALIDATION_PATH}/RFMiD_Validation_Labels.csv"


train_df = pd.read_csv(TRAINING_PATH_CSV)
train_df = train_df[["ID","Disease_Risk"]]

test_df = pd.read_csv(TESTING_PATH_CSV)
test_df = test_df[["ID","Disease_Risk"]]

validation_df = pd.read_csv(VALIDATION_PATH_CSV)
validation_df = validation_df[["ID","Disease_Risk"]]


# print(train_df["Disease_Risk"].value_counts(normalize=True))
print(train_df)

for i in train_df:
    print(i)
# Out:
#         ID  Disease_Risk
# 0        1             1
# 1        2             1
# 2        3             1
# 3        4             1
# 4        5             1
# ...    ...           ...
# 1915  1916             1
# 1916  1917             1
# 1917  1918             0
# 1918  1919             0
# 1919  1920             0
#
# [1920 rows x 2 columns]
# ID
# Disease_Risk

# %%
def append_ext(id):
        return f"{id}.png"

def convert_class(label):
        if label == 0:
            return "no"
        elif label == 1:
            return "yes"

train_df['name'] = train_df['ID'].apply(append_ext)
test_df['name'] = test_df['ID'].apply(append_ext)
validation_df['name'] = validation_df['ID'].apply(append_ext)

train_df['class'] = train_df['Disease_Risk']
test_df['class'] = test_df['Disease_Risk']
validation_df['class'] = validation_df['Disease_Risk']
# .apply(convert_class)

train_df = train_df.drop(["ID", "Disease_Risk"], axis=1)
test_df = test_df.drop(["ID", "Disease_Risk"], axis=1)
validation_df = validation_df.drop(["ID", "Disease_Risk"], axis=1)

# %%
display(train_df)
# display(test_df)
# display(validation_df)
# Out:
#           name  class
# 0        1.png      1
# 1        2.png      1
# 2        3.png      1
# 3        4.png      1
# 4        5.png      1
# ...        ...    ...
# 1915  1916.png      1
# 1916  1917.png      1
# 1917  1918.png      0
# 1918  1919.png      0
# 1919  1920.png      0
#
# [1920 rows x 2 columns]

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2


def create_circular_mask(image_height, image_width, center=None, radius=None):
    if center is None:  # use the middle of the image
        center = (image_width // 2, image_height // 2)
    if radius is None:  # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], image_width - center[0], image_height - center[1])

    Y, X = np.ogrid[:image_height, :image_width]
    dist_from_center = np.sqrt((X - center[0]) ** 2 + (Y - center[1]) ** 2)

    mask = dist_from_center <= radius
    return mask


def create_oval_mask(image_height, image_width, center=None, radius=None):
    if center is None:  # use the middle of the image
        center = (image_width // 2, image_height // 2)
    if radius is None:  # use the smallest distance between the center and image walls
        radius_x = center[0]
        radius_y = center[1]
    else:
        radius_x = radius[0]
        radius_y = radius[1]

    Y, X = np.ogrid[:image_height, :image_width]
    dist_from_center = ((X - center[0]) / radius_x) ** 2 + ((Y - center[1]) / radius_y) ** 2

    mask = dist_from_center <= 1
    return mask

def apply_mask(image, mask):
    image_array = np.array(image)  # Convert image to NumPy array
    masked_image = image_array.copy()
    masked_image[~mask] = 0
    return masked_image

def get_images_labels(image_folder_path, dataframe, limit=None, maskImages=False):
    # Load and preprocess images
	images = []
	labels = []

	if limit!=None:
		dataframe = dataframe[:limit]
	for index, row in dataframe.iterrows():
		image_path = os.path.join(image_folder_path, row['name'])
		# Assuming images are resized to (IMAGE_HEIGHT x IMAGE_HEIGHT) pixels
		image = load_img(image_path, color_mode=COLOR_MODE, target_size=(IMAGE_HEIGHT, IMAGE_WIDTH), interpolation='bilinear')
		
		if maskImages==True:
			# MASK STUFF
			center = (IMAGE_WIDTH // 2, IMAGE_HEIGHT // 2)
			# radius = min(center[0], center[1])
			# radius = 50
			# mask = create_circular_mask(IMAGE_HEIGHT, IMAGE_WIDTH, center, radius)
			radius=(50, 70)
			mask = create_oval_mask(IMAGE_HEIGHT, IMAGE_WIDTH, center, radius)
			# Apply the circular mask to an image
			masked_image = apply_mask(image, mask)
			# Rescale pixel values to [0, 1]
			final_image = img_to_array(masked_image) / 255.0
		else:
			final_image = img_to_array(image) / 255.0

		images.append(final_image)
		labels.append(row['class'])

	# Convert lists to NumPy arrays
	images = np.array(images)
	labels = np.array(labels)

	return images, labels

# %%
train_ds_images, train_ds_labels = get_images_labels(f"{TRAINING_PATH}/Training", train_df, limit=None, maskImages=True)
test_ds_images, test_ds_labels = get_images_labels(f"{TESTING_PATH}/Test", test_df, limit=None, maskImages=True)
validation_ds_images, validation_ds_labels = get_images_labels(f"{VALIDATION_PATH}/Validation", validation_df, limit=None, maskImages=True)
compare_ds_images, compare_ds_labels = get_images_labels(f"{VALIDATION_PATH}/Validation", validation_df, limit=5, maskImages=False)

# %%
from matplotlib import pyplot as plt

rows, cols = 2, 6
# Create a figure and subplots with 1 row and 3 columns
fig, axes = plt.subplots(2, 6, figsize=(15, 5))
l = 0
for i in range(rows):
	for j in range(cols):
		# Plot the original image
		axes[i, j].imshow(train_ds_images[l], interpolation='bilinear')
		axes[i, j].set_title(train_ds_labels[l])
		axes[i, j].axis('off')
		axes[i, j].imshow(test_ds_images[l], interpolation='bilinear')
		axes[i, j].set_title(test_ds_labels[l])
		axes[i, j].axis('off')
		l+=1

# %%
import numpy as np

def randomize_dataset(images, labels):
    # Generate shuffled indices
    num_samples = len(images)
    shuffled_indices = np.random.permutation(num_samples)

    # Shuffle images and labels
    shuffled_images = images[shuffled_indices]
    shuffled_labels = labels[shuffled_indices]

    return shuffled_images, shuffled_labels

# Randomize the images in each dataset
train_ds_images, train_ds_labels = randomize_dataset(train_ds_images, train_ds_labels)
test_ds_images, test_ds_labels = randomize_dataset(test_ds_images, test_ds_labels)
validation_ds_images, validation_ds_labels = randomize_dataset(validation_ds_images, validation_ds_labels)

# Example of randomized dataset
print("Randomized train dataset:")
print(train_ds_images.shape)
print(train_ds_labels.shape)
# Out:
# Randomized train dataset:
# (1920, 150, 150, 3)
# (1920,)

# %%
from matplotlib import pyplot as plt

rows, cols = 2, 6
# Create a figure and subplots with 1 row and 3 columns
fig, axes = plt.subplots(2, 6, figsize=(15, 5))
l = 0
for i in range(rows):
	for j in range(cols):
		# Plot the original image
		axes[i, j].imshow(train_ds_images[l], interpolation='bilinear')
		axes[i, j].set_title(train_ds_labels[l])
		axes[i, j].axis('off')
		axes[i, j].imshow(test_ds_images[l], interpolation='bilinear')
		axes[i, j].set_title(test_ds_labels[l])
		axes[i, j].axis('off')
		l+=1

# %%
# # Split data into training and testing sets
# x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
import keras

# # Define the CNN model
# model = Sequential([
#     Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(128, 128, 3)),
#     MaxPooling2D(pool_size=(2, 2)),
#     Conv2D(64, kernel_size=(3, 3), activation='relu'),
#     MaxPooling2D(pool_size=(2, 2)),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(1, activation='sigmoid')
# ])

model = keras.models.Sequential([
    keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, CHANNELS)),

    # preprocessing,

    # keras.layers.Conv2D(32, 3, padding="same", activation="relu"),
    keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(128, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    keras.layers.Conv2D(256, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    keras.layers.GlobalAveragePooling2D(),

    # keras.layers.Flatten(),
    # keras.layers.Dropout(0.2),
    # keras.layers.Dense(1024, activation="relu"),
    # keras.layers.Dropout(0.2),
    # keras.layers.Dense(256, activation="relu"),
    # keras.layers.Dropout(0.2),
    # keras.layers.Dense(32, activation="relu"),
    # keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation="sigmoid"), #sigmoid is for binary classification
])

# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(), 
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()],
)

model.summary(
    expand_nested=True,
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 150, 150, 64)      1792
#
#  max_pooling2d_8 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 75, 75, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_9 (Dropout)         (None, 37, 37, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 18, 18, 128)       0
#
#  conv2d_11 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 9, 9, 256)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 9, 9, 256)         0
#
#  global_average_pooling2d_2   (None, 256)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 408,001
# Trainable params: 408,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(len(train_ds_images), len(train_ds_labels))
print(len(validation_ds_images), len(validation_ds_labels))
# Out:
# 1920 1920
# 640 640

# %%
from sklearn.utils.class_weight import compute_class_weight

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_ds_labels), y=train_ds_labels)

# Convert class weights to a dictionary format
class_weights_dict = dict(enumerate(class_weights))

class_weights_dict

# %%
# # Train the model
EPOCHS = 100
PATIENCE = 25
earlystop_loss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

# Train the model
history = model.fit(
    x = train_ds_images,
    y = train_ds_labels,
    epochs=EPOCHS,
    batch_size=32,
    validation_data=(validation_ds_images, validation_ds_labels),
    callbacks=[earlystop_loss],
    class_weight=class_weights_dict,
)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 7s 101ms/step - loss: 0.6901 - binary_accuracy: 0.7547 - val_loss: 0.6399 - val_binary_accuracy: 0.7844
# Epoch 2/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6675 - binary_accuracy: 0.7026 - val_loss: 0.6139 - val_binary_accuracy: 0.6812
# Epoch 3/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6543 - binary_accuracy: 0.6396 - val_loss: 0.6907 - val_binary_accuracy: 0.3187
# Epoch 4/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6752 - binary_accuracy: 0.4120 - val_loss: 0.6911 - val_binary_accuracy: 0.3203
# Epoch 5/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6431 - binary_accuracy: 0.5620 - val_loss: 0.7262 - val_binary_accuracy: 0.2297
# Epoch 6/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6939 - binary_accuracy: 0.2156 - val_loss: 0.7225 - val_binary_accuracy: 0.2219
# Epoch 7/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6736 - binary_accuracy: 0.3672 - val_loss: 0.6833 - val_binary_accuracy: 0.3734
# Epoch 8/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6805 - binary_accuracy: 0.3385 - val_loss: 0.7267 - val_binary_accuracy: 0.2109
# Epoch 9/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6945 - binary_accuracy: 0.2099 - val_loss: 0.7187 - val_binary_accuracy: 0.2125
# Epoch 10/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6939 - binary_accuracy: 0.2115 - val_loss: 0.7121 - val_binary_accuracy: 0.2141
# Epoch 11/100
# 60/60 [==============================] - 6s 92ms/step - loss: 0.6934 - binary_accuracy: 0.2125 - val_loss: 0.7078 - val_binary_accuracy: 0.2156
# Epoch 12/100
# 60/60 [==============================] - 6s 94ms/step - loss: 0.6929 - binary_accuracy: 0.2172 - val_loss: 0.7029 - val_binary_accuracy: 0.2313
# Epoch 13/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.6691 - binary_accuracy: 0.3865 - val_loss: 0.7922 - val_binary_accuracy: 0.3453
# Epoch 14/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.6500 - binary_accuracy: 0.5255 - val_loss: 0.5334 - val_binary_accuracy: 0.7391
# Epoch 15/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.6086 - binary_accuracy: 0.6125 - val_loss: 0.5330 - val_binary_accuracy: 0.6734
# Epoch 16/100
# 60/60 [==============================] - 6s 95ms/step - loss: 0.6104 - binary_accuracy: 0.6078 - val_loss: 0.5734 - val_binary_accuracy: 0.6234
# Epoch 17/100
# 60/60 [==============================] - 6s 94ms/step - loss: 0.5956 - binary_accuracy: 0.5776 - val_loss: 0.6427 - val_binary_accuracy: 0.5203
# Epoch 18/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.6019 - binary_accuracy: 0.6682 - val_loss: 0.5867 - val_binary_accuracy: 0.6016
# Epoch 19/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.5936 - binary_accuracy: 0.6229 - val_loss: 0.5991 - val_binary_accuracy: 0.6141
# Epoch 20/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5858 - binary_accuracy: 0.6313 - val_loss: 0.6465 - val_binary_accuracy: 0.5813
# Epoch 21/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5559 - binary_accuracy: 0.6708 - val_loss: 0.5262 - val_binary_accuracy: 0.6859
# Epoch 22/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5502 - binary_accuracy: 0.6802 - val_loss: 0.6114 - val_binary_accuracy: 0.6000
# Epoch 23/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5464 - binary_accuracy: 0.6990 - val_loss: 0.5472 - val_binary_accuracy: 0.6656
# Epoch 24/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5342 - binary_accuracy: 0.7135 - val_loss: 0.6117 - val_binary_accuracy: 0.6047
# Epoch 25/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5328 - binary_accuracy: 0.7115 - val_loss: 0.4870 - val_binary_accuracy: 0.7312
# Epoch 26/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5242 - binary_accuracy: 0.7125 - val_loss: 0.5986 - val_binary_accuracy: 0.6234
# Epoch 27/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5313 - binary_accuracy: 0.7068 - val_loss: 0.6826 - val_binary_accuracy: 0.6078
# Epoch 28/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5313 - binary_accuracy: 0.7125 - val_loss: 0.7208 - val_binary_accuracy: 0.5188
# Epoch 29/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5157 - binary_accuracy: 0.7026 - val_loss: 0.5421 - val_binary_accuracy: 0.6812
# Epoch 30/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5036 - binary_accuracy: 0.7141 - val_loss: 0.4617 - val_binary_accuracy: 0.7328
# Epoch 31/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.5166 - binary_accuracy: 0.7156 - val_loss: 0.5947 - val_binary_accuracy: 0.6531
# Epoch 32/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5036 - binary_accuracy: 0.7120 - val_loss: 0.6708 - val_binary_accuracy: 0.5813
# Epoch 33/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5131 - binary_accuracy: 0.7240 - val_loss: 0.6603 - val_binary_accuracy: 0.6031
# Epoch 34/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5174 - binary_accuracy: 0.7036 - val_loss: 0.7098 - val_binary_accuracy: 0.5219
# Epoch 35/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5023 - binary_accuracy: 0.7260 - val_loss: 0.6948 - val_binary_accuracy: 0.5672
# Epoch 36/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4929 - binary_accuracy: 0.7203 - val_loss: 0.6063 - val_binary_accuracy: 0.6219
# Epoch 37/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4901 - binary_accuracy: 0.7370 - val_loss: 0.5255 - val_binary_accuracy: 0.6859
# Epoch 38/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5064 - binary_accuracy: 0.7115 - val_loss: 0.4968 - val_binary_accuracy: 0.7297
# Epoch 39/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4841 - binary_accuracy: 0.7323 - val_loss: 0.5749 - val_binary_accuracy: 0.6516
# Epoch 40/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.5094 - binary_accuracy: 0.7057 - val_loss: 0.5342 - val_binary_accuracy: 0.6766
# Epoch 41/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4999 - binary_accuracy: 0.7214 - val_loss: 0.4827 - val_binary_accuracy: 0.7188
# Epoch 42/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4881 - binary_accuracy: 0.7318 - val_loss: 0.5731 - val_binary_accuracy: 0.6516
# Epoch 43/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4859 - binary_accuracy: 0.7359 - val_loss: 0.5781 - val_binary_accuracy: 0.6766
# Epoch 44/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4829 - binary_accuracy: 0.7349 - val_loss: 0.4596 - val_binary_accuracy: 0.7344
# Epoch 45/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4912 - binary_accuracy: 0.7135 - val_loss: 0.6774 - val_binary_accuracy: 0.5484
# Epoch 46/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4873 - binary_accuracy: 0.7250 - val_loss: 0.5667 - val_binary_accuracy: 0.6516
# Epoch 47/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4818 - binary_accuracy: 0.7104 - val_loss: 0.4995 - val_binary_accuracy: 0.7078
# Epoch 48/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4848 - binary_accuracy: 0.7281 - val_loss: 0.5248 - val_binary_accuracy: 0.6984
# Epoch 49/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4677 - binary_accuracy: 0.7359 - val_loss: 0.5578 - val_binary_accuracy: 0.6812
# Epoch 50/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4823 - binary_accuracy: 0.7297 - val_loss: 0.5581 - val_binary_accuracy: 0.6609
# Epoch 51/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4645 - binary_accuracy: 0.7495 - val_loss: 0.6176 - val_binary_accuracy: 0.6422
# Epoch 52/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4712 - binary_accuracy: 0.7297 - val_loss: 0.6247 - val_binary_accuracy: 0.6281
# Epoch 53/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4785 - binary_accuracy: 0.7203 - val_loss: 0.5319 - val_binary_accuracy: 0.6922
# Epoch 54/100
# 60/60 [==============================] - 6s 94ms/step - loss: 0.4649 - binary_accuracy: 0.7271 - val_loss: 0.5100 - val_binary_accuracy: 0.6984
# Epoch 55/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.4592 - binary_accuracy: 0.7443 - val_loss: 0.4827 - val_binary_accuracy: 0.7141
# Epoch 56/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.4687 - binary_accuracy: 0.7255 - val_loss: 0.6751 - val_binary_accuracy: 0.5766
# Epoch 57/100
# 60/60 [==============================] - 6s 94ms/step - loss: 0.4621 - binary_accuracy: 0.7188 - val_loss: 0.5239 - val_binary_accuracy: 0.6859
# Epoch 58/100
# 60/60 [==============================] - 6s 94ms/step - loss: 0.4743 - binary_accuracy: 0.7250 - val_loss: 0.5073 - val_binary_accuracy: 0.7000
# Epoch 59/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.4639 - binary_accuracy: 0.7344 - val_loss: 0.5289 - val_binary_accuracy: 0.6797
# Epoch 60/100
# 60/60 [==============================] - 6s 93ms/step - loss: 0.4615 - binary_accuracy: 0.7281 - val_loss: 0.5376 - val_binary_accuracy: 0.6891
# Epoch 61/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4530 - binary_accuracy: 0.7479 - val_loss: 0.5823 - val_binary_accuracy: 0.6531
# Epoch 62/100
# 60/60 [==============================] - 6s 96ms/step - loss: 0.4729 - binary_accuracy: 0.7260 - val_loss: 0.4965 - val_binary_accuracy: 0.6922
# Epoch 63/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4535 - binary_accuracy: 0.7411 - val_loss: 0.4114 - val_binary_accuracy: 0.7797
# Epoch 64/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4666 - binary_accuracy: 0.7333 - val_loss: 0.5876 - val_binary_accuracy: 0.6641
# Epoch 65/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4660 - binary_accuracy: 0.7271 - val_loss: 0.5435 - val_binary_accuracy: 0.6734
# Epoch 66/100
# 60/60 [==============================] - 6s 97ms/step - loss: 0.4740 - binary_accuracy: 0.7479 - val_loss: 0.6480 - val_binary_accuracy: 0.6297
# Epoch 67/100
# 60/60 [==============================] - 6s 101ms/step - loss: 0.4554 - binary_accuracy: 0.7312 - val_loss: 0.5912 - val_binary_accuracy: 0.6516
# Epoch 68/100
# 60/60 [==============================] - 6s 103ms/step - loss: 0.4601 - binary_accuracy: 0.7234 - val_loss: 0.7787 - val_binary_accuracy: 0.5266
# Epoch 69/100
# 60/60 [==============================] - 6s 101ms/step - loss: 0.4738 - binary_accuracy: 0.7260 - val_loss: 0.4991 - val_binary_accuracy: 0.6984
# Epoch 70/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4406 - binary_accuracy: 0.7396 - val_loss: 0.4421 - val_binary_accuracy: 0.7531
# Epoch 71/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4398 - binary_accuracy: 0.7484 - val_loss: 0.5741 - val_binary_accuracy: 0.6500
# Epoch 72/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4367 - binary_accuracy: 0.7464 - val_loss: 0.5687 - val_binary_accuracy: 0.6656
# Epoch 73/100
# 60/60 [==============================] - 6s 100ms/step - loss: 0.4424 - binary_accuracy: 0.7484 - val_loss: 0.5323 - val_binary_accuracy: 0.7016
# Epoch 74/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4369 - binary_accuracy: 0.7484 - val_loss: 0.5499 - val_binary_accuracy: 0.6766
# Epoch 75/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4391 - binary_accuracy: 0.7510 - val_loss: 0.5653 - val_binary_accuracy: 0.6828
# Epoch 76/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4399 - binary_accuracy: 0.7479 - val_loss: 0.5339 - val_binary_accuracy: 0.6922
# Epoch 77/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4256 - binary_accuracy: 0.7375 - val_loss: 0.6436 - val_binary_accuracy: 0.6313
# Epoch 78/100
# 60/60 [==============================] - 6s 102ms/step - loss: 0.4314 - binary_accuracy: 0.7557 - val_loss: 0.6344 - val_binary_accuracy: 0.6422
# Epoch 79/100
# 60/60 [==============================] - 6s 104ms/step - loss: 0.4293 - binary_accuracy: 0.7458 - val_loss: 0.5393 - val_binary_accuracy: 0.6703
# Epoch 80/100
# 60/60 [==============================] - 6s 102ms/step - loss: 0.4829 - binary_accuracy: 0.7344 - val_loss: 0.5045 - val_binary_accuracy: 0.7047
# Epoch 81/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4357 - binary_accuracy: 0.7458 - val_loss: 0.4445 - val_binary_accuracy: 0.7563
# Epoch 82/100
# 60/60 [==============================] - 6s 100ms/step - loss: 0.4181 - binary_accuracy: 0.7667 - val_loss: 0.5120 - val_binary_accuracy: 0.7172
# Epoch 83/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4338 - binary_accuracy: 0.7578 - val_loss: 0.6611 - val_binary_accuracy: 0.6187
# Epoch 84/100
# 60/60 [==============================] - 6s 99ms/step - loss: 0.4099 - binary_accuracy: 0.7661 - val_loss: 0.5565 - val_binary_accuracy: 0.6828
# Epoch 85/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4218 - binary_accuracy: 0.7557 - val_loss: 0.5792 - val_binary_accuracy: 0.6625
# Epoch 86/100
# 60/60 [==============================] - 6s 98ms/step - loss: 0.4440 - binary_accuracy: 0.7521 - val_loss: 0.5329 - val_binary_accuracy: 0.6734
# Epoch 87/100
# 60/60 [==============================] - 6s 100ms/step - loss: 0.4125 - binary_accuracy: 0.7661 - val_loss: 0.6120 - val_binary_accuracy: 0.6547
# Epoch 88/100
# 60/60 [==============================] - 6s 102ms/step - loss: 0.4154 - binary_accuracy: 0.7542 - val_loss: 0.6212 - val_binary_accuracy: 0.6297

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_ds_images, test_ds_labels)
print("Test Accuracy:", test_accuracy)
# Out:
# 20/20 [==============================] - 1s 30ms/step - loss: 0.4322 - binary_accuracy: 0.7688
# Test Accuracy: 0.768750011920929

# %%
from matplotlib import pyplot as plt

print("Epochs run:", len(history.history["loss"]))

acc = history.history["binary_accuracy"]
val_acc = history.history["val_binary_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.ylim((0, 1))
plt.plot(epochs, acc, label="Training accurarcy")
plt.plot(epochs, val_acc, label="Validation accurarcy")
plt.title("Training and Validation accurarcy")
plt.legend()

# Train and validation loss
plt.subplot(1, 2, 2)

plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.title("Training and Validation loss")
plt.legend()
plt.show()
# Out:
# Epochs run: 88

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix


# validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
#     TESTING_FOLER,
#     image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
#     batch_size=32,
#     color_mode=COLOR_MODE,
#     shuffle=True,
# )

# Get true labels and predicted probabilities
true_labels = []

predictions = model.predict(test_ds_images)
# Convert probabilities to predicted labels
predicted_labels = np.where(np.array(predictions) > 0.5, 1, 0)

# Convert true labels and predicted labels to numpy arrays
true_labels = np.array(test_ds_labels)
predicted_labels = np.array(predicted_labels)

# Build the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print(conf_matrix)
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 20/20 [==============================] - 1s 22ms/step
# [[ 99  35]
#  [113 393]]
