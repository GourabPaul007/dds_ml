# %%
# import cv2
import numpy as np
# from tqdm import tqdm # progress bar for loops
import os
import tensorflow as tf

DATASET_FOLER = "tb-dataset/"
TRAINING_FOLER = DATASET_FOLER + "/" + "train"
TESTING_FOLER = DATASET_FOLER + "/" + "test"
IMAGE_HEIGHT=150
IMAGE_WIDTH=150
COLOR_MODE='grayscale'
IMAGE_CHANNELS = 3 if COLOR_MODE=='rgb' else 1
PATIENCE = 25
EPOCHS = 100

train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAINING_FOLER,
    batch_size=32,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    color_mode=COLOR_MODE,
    subset='training',
    validation_split=0.2,
    seed=42,
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    TRAINING_FOLER,
    batch_size=32,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    color_mode=COLOR_MODE,
    subset='validation',
    validation_split=0.2,
    seed=42,
)
# Out:
# Found 3780 files belonging to 2 classes.
# Using 3024 files for training.
# Found 3780 files belonging to 2 classes.
# Using 756 files for validation.

# %%
train_ds
im_ext = ['.jpg', '.JPG', '.jpeg', '.JPEG', '.png', '.PNG']
def hasExt(filename):
    for ext in im_ext:
        if filename.endswith(ext):
            return True
    return False

dirs = []
d = {0:0, 1:0}
n_samples = 0
path = './tb-dataset/train'
for i in os.listdir(path):
    if os.path.isdir(os.path.join(path, i)):
        dirs.append(path+"/"+i)
# init dictionary with values 0
for i in dirs:
    for j in os.listdir(i):
        imgPaths = i+"/"+j
        if os.path.isfile(imgPaths) and hasExt(imgPaths):
            n_samples += 1
            if "Normal" in i:
                d[0] += 1
            else:
                d[1] += 1
                
n_classes = len(dirs)
n_samples0 = d[0]
n_samples1 = d[1]
w0 = n_samples / (n_classes * n_samples0)
w1 = n_samples / (n_classes * n_samples1)
print(dirs)
print(n_samples)
print(n_classes)
print(d)
class_weights = {0: w0, 1: w1}
print(class_weights)
# Out:
# ['./tb-dataset/train/Normal', './tb-dataset/train/Tuberculosis']
# 3780
# 2
# {0: 3150, 1: 630}
# {0: 0.6, 1: 3.0}

# %%
class_names = train_ds.class_names
print(class_names)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(10):
    print(images[i].shape)
    ax = plt.subplot(2, 5, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ['Normal', 'Tuberculosis']
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)
# (150, 150, 1)

# %%
import tensorflow as tf
from tensorflow import keras

preprocessing = tf.keras.Sequential([
    tf.keras.layers.Resizing(IMAGE_HEIGHT, IMAGE_WIDTH),
    tf.keras.layers.Rescaling(1./255),
    # tf.keras.layers.CenterCrop(100, 100)
])

data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(1),
    keras.layers.RandomTranslation(0.2, 0.2),
    keras.layers.RandomZoom(0.2),
    keras.layers.RandomBrightness(0.2),
    keras.layers.RandomContrast(0.2),
])

train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# <ParallelMapDataset element_spec=(TensorSpec(shape=(None, 150, 150, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# # Calculate class weights
# class_counts = train_ds.reduce(
#     initial_state=tf.zeros(2), 
#     reduce_func=lambda state, batch: state + tf.cast(tf.math.reduce_sum(batch[1], axis=0), tf.float32)
# )
# # w0 = 
# total_samples = tf.reduce_sum(class_counts)
# class_weights = {0: total_samples / (2 * class_counts[0]), 1: total_samples / (2 * class_counts[1])}
# print(class_weights)

# %%
# from tensorflow import keras
# from keras.models import Sequential
# from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization

# model = Sequential()
# model.add(keras.layers.Input(shape=(None, None, IMAGE_CHANNELS)))
# model.add(preprocessing)

# # model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
# model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
# model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
# model.add(Flatten())
# model.add(Dense(units = 128 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 1 , activation = 'sigmoid'))
# model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# model.summary()

# %%
model = keras.models.Sequential([
    keras.layers.Input(shape=(None, None, IMAGE_CHANNELS)),

    preprocessing,

    keras.layers.Conv2D(32, 3, padding="same", activation="relu"),
    keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(128, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    keras.layers.Conv2D(256, 3, padding="same", activation="relu"),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),

    # keras.layers.Conv2D(256, 3, padding="same", activation="relu"),
    # # keras.layers.BatchNormalization(momentum=0.87),
    # keras.layers.MaxPooling2D(),

    keras.layers.GlobalAveragePooling2D(),

    # keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation="sigmoid"), #sigmoid is for binary classification
])


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()],
)

model.summary(
    expand_nested=True,
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 150, 150, 1)       0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | resizing (Resizing)       (None, 150, 150, 1)       0         |
# |                                                               |
# | rescaling (Rescaling)     (None, 150, 150, 1)       0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 37, 37, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 18, 18, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 9, 9, 256)         0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 425,025
# Trainable params: 425,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

earlystop_loss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)
# earlystop_loss = tf.keras.callbacks.EarlyStopping(monitor='val_binary_accuracy', patience=PATIENCE, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[earlystop_loss],
    class_weight=class_weights,
)
# Out:
# Epoch 1/100
# 95/95 [==============================] - 23s 172ms/step - loss: 0.6863 - binary_accuracy: 0.7424 - val_loss: 0.6636 - val_binary_accuracy: 0.8135
# Epoch 2/100
# 95/95 [==============================] - 15s 157ms/step - loss: 0.6655 - binary_accuracy: 0.7487 - val_loss: 0.5394 - val_binary_accuracy: 0.7209
# Epoch 3/100
# 95/95 [==============================] - 16s 165ms/step - loss: 0.5547 - binary_accuracy: 0.6997 - val_loss: 0.3883 - val_binary_accuracy: 0.8347
# Epoch 4/100
# 95/95 [==============================] - 16s 166ms/step - loss: 0.4014 - binary_accuracy: 0.8022 - val_loss: 0.3254 - val_binary_accuracy: 0.8624
# Epoch 5/100
# 95/95 [==============================] - 17s 172ms/step - loss: 0.3085 - binary_accuracy: 0.8548 - val_loss: 0.2354 - val_binary_accuracy: 0.8995
# Epoch 6/100
# 95/95 [==============================] - 16s 165ms/step - loss: 0.2818 - binary_accuracy: 0.8767 - val_loss: 0.2453 - val_binary_accuracy: 0.8823
# Epoch 7/100
# 95/95 [==============================] - 16s 164ms/step - loss: 0.1963 - binary_accuracy: 0.9041 - val_loss: 0.1812 - val_binary_accuracy: 0.9153
# Epoch 8/100
# 95/95 [==============================] - 16s 163ms/step - loss: 0.1722 - binary_accuracy: 0.9282 - val_loss: 0.1466 - val_binary_accuracy: 0.9444
# Epoch 9/100
# 95/95 [==============================] - 16s 163ms/step - loss: 0.1611 - binary_accuracy: 0.9256 - val_loss: 0.1328 - val_binary_accuracy: 0.9444
# Epoch 10/100
# 95/95 [==============================] - 16s 164ms/step - loss: 0.1261 - binary_accuracy: 0.9454 - val_loss: 0.1352 - val_binary_accuracy: 0.9431
# Epoch 11/100
# 95/95 [==============================] - 16s 164ms/step - loss: 0.1100 - binary_accuracy: 0.9577 - val_loss: 0.1015 - val_binary_accuracy: 0.9656
# Epoch 12/100
# 95/95 [==============================] - 16s 165ms/step - loss: 0.1029 - binary_accuracy: 0.9640 - val_loss: 0.1437 - val_binary_accuracy: 0.9471
# Epoch 13/100
# 95/95 [==============================] - 16s 165ms/step - loss: 0.0996 - binary_accuracy: 0.9600 - val_loss: 0.1071 - val_binary_accuracy: 0.9616
# Epoch 14/100
# 95/95 [==============================] - 16s 165ms/step - loss: 0.1091 - binary_accuracy: 0.9514 - val_loss: 0.0816 - val_binary_accuracy: 0.9722
# Epoch 15/100
# 95/95 [==============================] - 16s 168ms/step - loss: 0.0671 - binary_accuracy: 0.9729 - val_loss: 0.0832 - val_binary_accuracy: 0.9709
# Epoch 16/100
# 95/95 [==============================] - 16s 166ms/step - loss: 0.0696 - binary_accuracy: 0.9689 - val_loss: 0.0821 - val_binary_accuracy: 0.9722
# Epoch 17/100
# 95/95 [==============================] - 16s 166ms/step - loss: 0.0543 - binary_accuracy: 0.9782 - val_loss: 0.0869 - val_binary_accuracy: 0.9722
# Epoch 18/100
# 95/95 [==============================] - 16s 167ms/step - loss: 0.1161 - binary_accuracy: 0.9580 - val_loss: 0.2693 - val_binary_accuracy: 0.8981
# Epoch 19/100
# 95/95 [==============================] - 16s 169ms/step - loss: 0.0549 - binary_accuracy: 0.9765 - val_loss: 0.0697 - val_binary_accuracy: 0.9762
# Epoch 20/100
# 95/95 [==============================] - 16s 168ms/step - loss: 0.0634 - binary_accuracy: 0.9772 - val_loss: 0.1051 - val_binary_accuracy: 0.9630
# Epoch 21/100
# 95/95 [==============================] - 16s 170ms/step - loss: 0.0286 - binary_accuracy: 0.9884 - val_loss: 0.0783 - val_binary_accuracy: 0.9749
# Epoch 22/100
# 95/95 [==============================] - 16s 166ms/step - loss: 0.0375 - binary_accuracy: 0.9861 - val_loss: 0.0648 - val_binary_accuracy: 0.9802
# Epoch 23/100
# 95/95 [==============================] - 16s 167ms/step - loss: 0.0308 - binary_accuracy: 0.9888 - val_loss: 0.0953 - val_binary_accuracy: 0.9683
# Epoch 24/100
# 95/95 [==============================] - 17s 173ms/step - loss: 0.0398 - binary_accuracy: 0.9845 - val_loss: 0.0654 - val_binary_accuracy: 0.9841
# Epoch 25/100
# 95/95 [==============================] - 17s 174ms/step - loss: 0.0505 - binary_accuracy: 0.9805 - val_loss: 0.1283 - val_binary_accuracy: 0.9444
# Epoch 26/100
# 95/95 [==============================] - 16s 169ms/step - loss: 0.0291 - binary_accuracy: 0.9894 - val_loss: 0.0552 - val_binary_accuracy: 0.9815
# Epoch 27/100
# 95/95 [==============================] - 17s 171ms/step - loss: 0.0317 - binary_accuracy: 0.9917 - val_loss: 0.0699 - val_binary_accuracy: 0.9828
# Epoch 28/100
# 95/95 [==============================] - 17s 178ms/step - loss: 0.0341 - binary_accuracy: 0.9878 - val_loss: 0.0697 - val_binary_accuracy: 0.9722
# Epoch 29/100
# 95/95 [==============================] - 19s 202ms/step - loss: 0.0221 - binary_accuracy: 0.9914 - val_loss: 0.0621 - val_binary_accuracy: 0.9788
# Epoch 30/100
# 95/95 [==============================] - 25s 258ms/step - loss: 0.0485 - binary_accuracy: 0.9802 - val_loss: 0.0646 - val_binary_accuracy: 0.9775
# Epoch 31/100
# 95/95 [==============================] - 15s 161ms/step - loss: 0.0205 - binary_accuracy: 0.9927 - val_loss: 0.0509 - val_binary_accuracy: 0.9881
# Epoch 32/100
# 95/95 [==============================] - 24s 249ms/step - loss: 0.0071 - binary_accuracy: 0.9974 - val_loss: 0.0452 - val_binary_accuracy: 0.9881
# Epoch 33/100
# 95/95 [==============================] - 21s 213ms/step - loss: 0.0133 - binary_accuracy: 0.9957 - val_loss: 0.0741 - val_binary_accuracy: 0.9735
# Epoch 34/100
# 95/95 [==============================] - 20s 203ms/step - loss: 0.0167 - binary_accuracy: 0.9934 - val_loss: 0.0577 - val_binary_accuracy: 0.9868
# Epoch 35/100
# 95/95 [==============================] - 15s 156ms/step - loss: 0.0096 - binary_accuracy: 0.9977 - val_loss: 0.0584 - val_binary_accuracy: 0.9841
# Epoch 36/100
# 95/95 [==============================] - 17s 174ms/step - loss: 0.0323 - binary_accuracy: 0.9888 - val_loss: 0.1120 - val_binary_accuracy: 0.9828
# Epoch 37/100
# 95/95 [==============================] - 18s 184ms/step - loss: 0.0430 - binary_accuracy: 0.9851 - val_loss: 0.0462 - val_binary_accuracy: 0.9894
# Epoch 38/100
# 95/95 [==============================] - 20s 202ms/step - loss: 0.0190 - binary_accuracy: 0.9937 - val_loss: 0.0511 - val_binary_accuracy: 0.9881
# Epoch 39/100
# 95/95 [==============================] - 21s 218ms/step - loss: 0.0066 - binary_accuracy: 0.9974 - val_loss: 0.0417 - val_binary_accuracy: 0.9881
# Epoch 40/100
# 95/95 [==============================] - 15s 159ms/step - loss: 0.0046 - binary_accuracy: 0.9977 - val_loss: 0.0962 - val_binary_accuracy: 0.9683
# Epoch 41/100
# 95/95 [==============================] - 19s 198ms/step - loss: 0.0336 - binary_accuracy: 0.9864 - val_loss: 0.1195 - val_binary_accuracy: 0.9762
# Epoch 42/100
# 95/95 [==============================] - 15s 157ms/step - loss: 0.0182 - binary_accuracy: 0.9927 - val_loss: 0.0926 - val_binary_accuracy: 0.9696
# Epoch 43/100
# 95/95 [==============================] - 15s 156ms/step - loss: 0.0603 - binary_accuracy: 0.9759 - val_loss: 0.0777 - val_binary_accuracy: 0.9775
# Epoch 44/100
# 95/95 [==============================] - 15s 160ms/step - loss: 0.0359 - binary_accuracy: 0.9874 - val_loss: 0.0615 - val_binary_accuracy: 0.9775
# Epoch 45/100
# 95/95 [==============================] - 15s 154ms/step - loss: 0.0148 - binary_accuracy: 0.9934 - val_loss: 0.0685 - val_binary_accuracy: 0.9815
# Epoch 46/100
# 95/95 [==============================] - 15s 155ms/step - loss: 0.0055 - binary_accuracy: 0.9977 - val_loss: 0.0724 - val_binary_accuracy: 0.9921
# Epoch 47/100
# 95/95 [==============================] - 15s 154ms/step - loss: 0.0013 - binary_accuracy: 1.0000 - val_loss: 0.0617 - val_binary_accuracy: 0.9921
# Epoch 48/100
# 95/95 [==============================] - 18s 190ms/step - loss: 0.0102 - binary_accuracy: 0.9970 - val_loss: 0.0966 - val_binary_accuracy: 0.9868
# Epoch 49/100
# 95/95 [==============================] - 20s 203ms/step - loss: 0.0162 - binary_accuracy: 0.9914 - val_loss: 0.0408 - val_binary_accuracy: 0.9921
# Epoch 50/100
# 95/95 [==============================] - 20s 204ms/step - loss: 0.0122 - binary_accuracy: 0.9957 - val_loss: 0.0737 - val_binary_accuracy: 0.9762
# Epoch 51/100
# 95/95 [==============================] - 20s 204ms/step - loss: 0.0052 - binary_accuracy: 0.9980 - val_loss: 0.0312 - val_binary_accuracy: 0.9921
# Epoch 52/100
# 95/95 [==============================] - 20s 205ms/step - loss: 0.0010 - binary_accuracy: 0.9997 - val_loss: 0.0469 - val_binary_accuracy: 0.9907
# Epoch 53/100
# 95/95 [==============================] - 20s 205ms/step - loss: 0.0025 - binary_accuracy: 0.9993 - val_loss: 0.0381 - val_binary_accuracy: 0.9921
# Epoch 54/100
# 95/95 [==============================] - 20s 204ms/step - loss: 4.4340e-04 - binary_accuracy: 1.0000 - val_loss: 0.0448 - val_binary_accuracy: 0.9921
# Epoch 55/100
# 95/95 [==============================] - 20s 204ms/step - loss: 2.5570e-04 - binary_accuracy: 1.0000 - val_loss: 0.0433 - val_binary_accuracy: 0.9921
# Epoch 56/100
# 95/95 [==============================] - 20s 204ms/step - loss: 2.0228e-04 - binary_accuracy: 1.0000 - val_loss: 0.0446 - val_binary_accuracy: 0.9921
# Epoch 57/100
# 95/95 [==============================] - 20s 205ms/step - loss: 7.6395e-04 - binary_accuracy: 1.0000 - val_loss: 0.0481 - val_binary_accuracy: 0.9947
# Epoch 58/100
# 95/95 [==============================] - 20s 205ms/step - loss: 0.0013 - binary_accuracy: 0.9993 - val_loss: 0.0535 - val_binary_accuracy: 0.9907
# Epoch 59/100
# 95/95 [==============================] - 20s 212ms/step - loss: 3.8994e-04 - binary_accuracy: 1.0000 - val_loss: 0.0546 - val_binary_accuracy: 0.9907
# Epoch 60/100
# 95/95 [==============================] - 15s 157ms/step - loss: 2.0697e-04 - binary_accuracy: 1.0000 - val_loss: 0.0560 - val_binary_accuracy: 0.9907
# Epoch 61/100
# 95/95 [==============================] - 15s 157ms/step - loss: 6.9111e-04 - binary_accuracy: 0.9997 - val_loss: 0.0470 - val_binary_accuracy: 0.9934
# Epoch 62/100
# 95/95 [==============================] - 15s 157ms/step - loss: 0.0210 - binary_accuracy: 0.9931 - val_loss: 0.1692 - val_binary_accuracy: 0.9683
# Epoch 63/100
# 95/95 [==============================] - 16s 162ms/step - loss: 0.0934 - binary_accuracy: 0.9742 - val_loss: 0.0449 - val_binary_accuracy: 0.9868
# Epoch 64/100
# 95/95 [==============================] - 23s 236ms/step - loss: 0.0386 - binary_accuracy: 0.9868 - val_loss: 0.0305 - val_binary_accuracy: 0.9907
# Epoch 65/100
# 95/95 [==============================] - 21s 221ms/step - loss: 0.0330 - binary_accuracy: 0.9891 - val_loss: 0.0246 - val_binary_accuracy: 0.9907
# Epoch 66/100
# 95/95 [==============================] - 21s 220ms/step - loss: 0.0047 - binary_accuracy: 0.9983 - val_loss: 0.0313 - val_binary_accuracy: 0.9947
# Epoch 67/100
# 95/95 [==============================] - 21s 220ms/step - loss: 0.0069 - binary_accuracy: 0.9977 - val_loss: 0.0408 - val_binary_accuracy: 0.9934
# Epoch 68/100
# 95/95 [==============================] - 21s 216ms/step - loss: 0.0038 - binary_accuracy: 0.9987 - val_loss: 0.0349 - val_binary_accuracy: 0.9894
# Epoch 69/100
# 95/95 [==============================] - 15s 160ms/step - loss: 0.0154 - binary_accuracy: 0.9937 - val_loss: 0.0450 - val_binary_accuracy: 0.9894
# Epoch 70/100
# 95/95 [==============================] - 21s 220ms/step - loss: 0.0030 - binary_accuracy: 0.9987 - val_loss: 0.0366 - val_binary_accuracy: 0.9921
# Epoch 71/100
# 95/95 [==============================] - 21s 220ms/step - loss: 9.7394e-04 - binary_accuracy: 1.0000 - val_loss: 0.0416 - val_binary_accuracy: 0.9934
# Epoch 72/100
# 95/95 [==============================] - 18s 189ms/step - loss: 9.4991e-04 - binary_accuracy: 0.9997 - val_loss: 0.0550 - val_binary_accuracy: 0.9921
# Epoch 73/100
# 95/95 [==============================] - 21s 220ms/step - loss: 3.6571e-04 - binary_accuracy: 1.0000 - val_loss: 0.0582 - val_binary_accuracy: 0.9921
# Epoch 74/100
# 95/95 [==============================] - 21s 220ms/step - loss: 4.7142e-04 - binary_accuracy: 1.0000 - val_loss: 0.0456 - val_binary_accuracy: 0.9934
# Epoch 75/100
# 95/95 [==============================] - 21s 221ms/step - loss: 2.4739e-04 - binary_accuracy: 1.0000 - val_loss: 0.0508 - val_binary_accuracy: 0.9934
# Epoch 76/100
# 95/95 [==============================] - 21s 220ms/step - loss: 1.7614e-04 - binary_accuracy: 1.0000 - val_loss: 0.0618 - val_binary_accuracy: 0.9907
# Epoch 77/100
# 95/95 [==============================] - 21s 222ms/step - loss: 1.8573e-04 - binary_accuracy: 1.0000 - val_loss: 0.0524 - val_binary_accuracy: 0.9934
# Epoch 78/100
# 95/95 [==============================] - 21s 221ms/step - loss: 2.3324e-04 - binary_accuracy: 1.0000 - val_loss: 0.0524 - val_binary_accuracy: 0.9934
# Epoch 79/100
# 95/95 [==============================] - 21s 220ms/step - loss: 1.4461e-04 - binary_accuracy: 1.0000 - val_loss: 0.0543 - val_binary_accuracy: 0.9934
# Epoch 80/100
# 95/95 [==============================] - 21s 220ms/step - loss: 9.0445e-05 - binary_accuracy: 1.0000 - val_loss: 0.0509 - val_binary_accuracy: 0.9934
# Epoch 81/100
# 95/95 [==============================] - 21s 220ms/step - loss: 1.0352e-04 - binary_accuracy: 1.0000 - val_loss: 0.0564 - val_binary_accuracy: 0.9934
# Epoch 82/100
# 95/95 [==============================] - 21s 220ms/step - loss: 7.6797e-05 - binary_accuracy: 1.0000 - val_loss: 0.0624 - val_binary_accuracy: 0.9921
# Epoch 83/100
# 95/95 [==============================] - 21s 221ms/step - loss: 1.6384e-04 - binary_accuracy: 1.0000 - val_loss: 0.0810 - val_binary_accuracy: 0.9907
# Epoch 84/100
# 95/95 [==============================] - 21s 220ms/step - loss: 0.0092 - binary_accuracy: 0.9964 - val_loss: 0.1167 - val_binary_accuracy: 0.9709
# Epoch 85/100
# 95/95 [==============================] - 21s 219ms/step - loss: 0.0413 - binary_accuracy: 0.9874 - val_loss: 0.0666 - val_binary_accuracy: 0.9881
# Epoch 86/100
# 95/95 [==============================] - 20s 205ms/step - loss: 0.0177 - binary_accuracy: 0.9937 - val_loss: 0.0317 - val_binary_accuracy: 0.9907
# Epoch 87/100
# 95/95 [==============================] - 15s 150ms/step - loss: 0.0172 - binary_accuracy: 0.9921 - val_loss: 0.0640 - val_binary_accuracy: 0.9881
# Epoch 88/100
# 95/95 [==============================] - 14s 145ms/step - loss: 0.0051 - binary_accuracy: 0.9980 - val_loss: 0.0641 - val_binary_accuracy: 0.9907
# Epoch 89/100
# 95/95 [==============================] - 14s 144ms/step - loss: 0.0012 - binary_accuracy: 1.0000 - val_loss: 0.0574 - val_binary_accuracy: 0.9921
# Epoch 90/100
# 95/95 [==============================] - 14s 145ms/step - loss: 2.7536e-04 - binary_accuracy: 1.0000 - val_loss: 0.0799 - val_binary_accuracy: 0.9907

# %%
from matplotlib import pyplot as plt

print("Epochs run:", len(history.history["loss"]))

acc = history.history["binary_accuracy"]
val_acc = history.history["val_binary_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.ylim((0, 1))
plt.plot(epochs, acc, label="Training accurarcy")
plt.plot(epochs, val_acc, label="Validation accurarcy")
plt.title("Training and Validation accurarcy")
plt.legend()

# Train and validation loss
plt.subplot(1, 2, 2)

plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.title("Training and Validation loss")
plt.legend()
plt.show()
# Out:
# Epochs run: 90

# %%
import tensorflow as tf

test_ds = keras.utils.image_dataset_from_directory(TESTING_FOLER,
                                                   color_mode=COLOR_MODE,
                                                   batch_size=32,
                                                   image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                )


preprocessing = tf.keras.Sequential([
    # tf.keras.layers.Resizing(IMAGE_HEIGHT, IMAGE_WIDTH),
    tf.keras.layers.Rescaling(1./255),
    # tf.keras.layers.CenterCrop(100, 100)
])

# Preprocess the test dataset
test_ds_preprocessed = test_ds.map(lambda x, y: (preprocessing(x), y))


y_pred = model.evaluate(test_ds, verbose=0)
prediction = model.predict(test_ds)

print("Test accuracy:", y_pred[1]*100)
print("Test loss:", y_pred[0]*100)
# Out:
# Found 420 files belonging to 2 classes.
# 14/14 [==============================] - 1s 34ms/step
# Test accuracy: 98.33333492279053
# Test loss: 8.480837941169739

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix


validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TESTING_FOLER,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=32,
    color_mode=COLOR_MODE,
    shuffle=True,
)

validation_dataset = val_ds

# Get true labels and predicted probabilities
true_labels = []
predicted_probabilities = []

# Iterate over the validation dataset
for images, labels in validation_dataset:
    true_labels.extend(labels.numpy())
    predictions = model.predict(images)
    predicted_probabilities.extend(predictions)

# Convert probabilities to predicted labels
predicted_labels = np.where(np.array(predicted_probabilities) > 0.5, 1, 0)

# Convert true labels and predicted labels to numpy arrays
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Build the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print(conf_matrix)
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 420 files belonging to 2 classes.
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 85ms/step
# [[611   4]
#  [  3 138]]

# %%
# SAVING THE MODEL

# save the iris classification model
model.save("tb-cnn.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # SAVING THE MODEL
#       2
#       3 # save the iris classification model
# ----> 4 model.save("tb-cnn.h5")
#
# NameError: name 'model' is not defined

# %%
import tensorflow as tf

loaded_model = tf.keras.models.load_model("tb-cnn.h5") 
loss, accuracy = loaded_model.evaluate(test_ds)
# Out:
# 14/14 [==============================] - 1s 15ms/step - loss: 0.1060 - binary_accuracy: 0.9810
