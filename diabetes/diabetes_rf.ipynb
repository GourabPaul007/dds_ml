# %%
# import numpy as np
# import pandas as pd

# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler

# import seaborn as sns

# import tensorflow as tf
# from tensorflow import keras

# %%
# READ FROM CSV AND CREATE A DATA FRAME

import pandas as pd

df = pd.read_csv('../datasets/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# SPLIT DF_MALE INTO x & Y
# x = INDEPENDENT VARIABLES
# Y = EPENDENT VARIABLES
y = df['Outcome'].copy()
x = df.drop('Outcome', axis="columns")

y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# HANDLE ADTA IMBALANCE - INCREASE/DECREASE ROWS WITH CLASS VALUES(0/1) IF ONE IS LOWER IN NUMBER
# FOR BETTER TRAINING

from imblearn.over_sampling import SMOTE

X_balanced, y_balanced = SMOTE().fit_resample(x, y)
y_balanced.value_counts()
# Out:
# 1    500
# 0    500
# Name: Outcome, dtype: int64

# %%
# TRAIN-TEST SPLIT
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_train, x_test, y_train, y_test = train_test_split(X_balanced, y_balanced, train_size=0.8, random_state=42)

# Scale x with a standard scaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = pd.DataFrame(scaler.transform(x_train), columns=x.columns)
x_test = pd.DataFrame(scaler.transform(x_test), columns=x.columns)

# %%
y_train
# Out:
# 29     0
# 535    1
# 695    1
# 557    0
# 836    1
#       ..
# 106    0
# 270    1
# 860    1
# 435    1
# 102    0
# Name: Outcome, Length: 800, dtype: int64

# %%
# TRAIN THE MODEL WITH SVM

from sklearn.svm import SVC # "Support vector classifier"  
model = SVC(C=1000, gamma=0.1, kernel='rbf', random_state=42)  
model.fit(x_train, y_train)
# Out:
# SVC(C=1000, gamma=0.1, random_state=42)

# %%
# HYPER PARAMETER TUNING

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
  
# defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000], 
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel': ['rbf']} 
param_grid = {
    'n_estimators':[400],
    'criterion':["gini", "entropy", "log_loss"],
    'min_samples_split':[2, 5, 10, 20], 
    'min_samples_leaf':[1], 
    'max_features':["sqrt", "log2"], 
    'max_depth':[30, 50, 70, 100], 
    'bootstrap':[False], 
    'random_state':[9],

    'n_jobs':[4, 10],
} 
  
grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, cv=5, verbose = 3)
  
# fitting the model for grid search
grid.fit(x_train, y_train)

# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   2.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.838 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.838 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   2.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.838 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.838 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   2.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.838 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.838 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.1s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.4s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   1.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=70, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# ...
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.756 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.844 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   2.2s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.844 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.769 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.769 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.831 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.4s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.762 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.762 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.775 total time=   1.7s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.819 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.775 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.819 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.769 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.769 total time=   1.9s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.812 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.794 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.781 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.800 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=4, random_state=9;, score=0.806 total time=   0.3s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.781 total time=   2.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.787 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.800 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_depth=100, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=400, n_jobs=10, random_state=9;, score=0.806 total time=   0.3s
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 400, 'n_jobs': 4, 'random_state': 9}
# RandomForestClassifier(bootstrap=False, max_depth=30, min_samples_split=5,
#                        n_estimators=400, n_jobs=4, random_state=9)

# %%
# PREDICT RESULTS

y_pred = model.predict(x_test) 
# train_pred = model.predict(x_train)

pred = model.score(x_test, y_test)
print(f"Accuracy : {pred * 100}%")
# Out:
# Accuracy : 76.5%

# %%
from sklearn.ensemble import RandomForestClassifier


# rf = RandomForestClassifier(
#     n_estimators=400, 
#     min_samples_split=5, 
#     min_samples_leaf=1, 
#     max_features="sqrt", 
#     max_depth=76, 
#     bootstrap=False, 
#     random_state=9
# )
rf = RandomForestClassifier(
    bootstrap=False, 
    max_depth=30, 
    min_samples_split=5,
    n_estimators=400, 
    n_jobs=4, 
    random_state=9
)
rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# 0.805

# %%
# PREDICT RESULTS

y_pred = rf.predict(x_test) 
# train_pred = rf.predict(x_train)

pred = rf.score(x_test, y_test)
print(f"Accuracy : {pred * 100}%")
# Out:
# Accuracy : 80.5%

# %%
# CONFUSION MATRIX

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.metrics import confusion_matrix  
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
# MANUAL CHECKING BY PUTTING ROW VALUES

row = 8
y_pred = rf.predict(x_test.iloc[[row]])
res = y_pred[0]
print('prediction => ', res)
print('real => ', y_test.iloc[[row]])
# Out:
# prediction =>  1
# real =>  859    1
# Name: Outcome, dtype: int64

# %%
# # SAVING THE MODEL USING PICKLE PACKAGE

# import pickle

# # save the iris classification model as a pickle file
# model_pkl_file = "../pickles/diabetes-rf.pkl"  

# with open(model_pkl_file, 'wb') as file:  
#     pickle.dump(rf, file)

# %%
# # LOAD AND USE THE SAVED MODEL USING PICKLE PACKAGE
# with open(model_pkl_file, 'rb') as file:  
#     model = pickle.load(file)

# # evaluate model 
# y_pred = model.predict(x_test)

# # check results
# pred = model.score(x_test, y_test)
# print(f"Accuracy : {pred * 100}%")
# Out:
# Accuracy : 76.5%
