# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./Dataset/cancer_patient_data_sets.csv')
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
### Let's check the details of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %%
### shape of the dataset
df.shape
# Out:
# (1000, 26)

# %%
### checking for null values
df.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
### drop unnecessary clms from dataset
df.drop(columns=['index', 'Patient Id'], axis=1, inplace=True)
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
df['Level'].value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
### we need to change the level from categorical to numerical
df["Level"].replace({'High': 2, 'Medium': 1, 'Low': 0}, inplace=True)
print('Cancer Levels: ', df['Level'].unique())
# Out:
# Cancer Levels:  [0 1 2]

# %%
### detect outliers
### no outliers presents in this dataset

# %%
### make sure there are no categorical clms present
df.dtypes
# Out:
# Age                         int64
# Gender                      int64
# Air Pollution               int64
# Alcohol use                 int64
# Dust Allergy                int64
# OccuPational Hazards        int64
# Genetic Risk                int64
# chronic Lung Disease        int64
# Balanced Diet               int64
# Obesity                     int64
# Smoking                     int64
# Passive Smoker              int64
# Chest Pain                  int64
# Coughing of Blood           int64
# Fatigue                     int64
# Weight Loss                 int64
# Shortness of Breath         int64
# Wheezing                    int64
# Swallowing Difficulty       int64
# Clubbing of Finger Nails    int64
# Frequent Cold               int64
# Dry Cough                   int64
# Snoring                     int64
# Level                       int64
# dtype: object

# %%
corr_metrix = df.corr()
corr_metrix['Level']*100
# Out:
# Age                           6.004781
# Gender                      -16.498516
# Air Pollution                63.603849
# Alcohol use                  71.871032
# Dust Allergy                 71.383879
# OccuPational Hazards         67.325488
# Genetic Risk                 70.130272
# chronic Lung Disease         60.997133
# Balanced Diet                70.627302
# Obesity                      82.743510
# Smoking                      51.953015
# Passive Smoker               70.359442
# Chest Pain                   64.546118
# Coughing of Blood            78.209168
# Fatigue                      62.511363
# Weight Loss                  35.273755
# Shortness of Breath          49.702425
# Wheezing                     24.279380
# Swallowing Difficulty        24.914177
# Clubbing of Finger Nails     28.006285
# Frequent Cold                44.401677
# Dry Cough                    37.396836
# Snoring                      28.936595
# Level                       100.000000
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr_metrix, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,7))
colors = ['blue', 'red', 'green']
plt.title("Lung Cancer Chances ")
plt.pie(df['Level'].value_counts(), explode = (0.1, 0.02, 0.02), labels = ['High', 'Medium', 'Low'], autopct = "%1.2f%%", colors = colors)
plt.legend(title = "Lung Cancer Chances", loc = "lower left")

# %%
sns.displot(df['Level'], kde=True, color = 'red')

# %%
### data  preprocessing is done
df.to_csv('./Dataset/processed_dataset.csv', index=False)
