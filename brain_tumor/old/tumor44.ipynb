# %%
import tensorflow as tf
from tensorflow import keras
import os

print(tf.__version__)
# Out:
# 2.10.1

# %%
DATASET_DIR = './Datasets/BTDS_44C'
TRAIN_DIR = F"{DATASET_DIR}/train"
TEST_DIR = F"{DATASET_DIR}/test/"
EPOCHS = 200
BATCH_SIZE = 32
IMAGE_HEIGHT = 64
IMAGE_WIDTH = 64
IMAGE_CHANNELS = 1
IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
folders = len(next(os.walk(TRAIN_DIR))[1])
print(folders)
NUM_CLASSES = folders
PATIENCE = 25
AUTOTUNE = tf.data.AUTOTUNE
COLOR_MODE = 'rgb'
INPUT_DIM = 3 if COLOR_MODE=='rgb' else 1
# Out:
# 44

# %%
train_ds = keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    color_mode = COLOR_MODE,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    batch_size = BATCH_SIZE,
)

val_ds = keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    color_mode = COLOR_MODE,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    batch_size = BATCH_SIZE,
)
# Out:
# Found 4053 files belonging to 44 classes.
# Using 3243 files for training.
# Found 4053 files belonging to 44 classes.
# Using 810 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    print(images[i].shape)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ['Astrocitoma T1', 'Astrocitoma T1C+', 'Astrocitoma T2', 'Carcinoma T1', 'Carcinoma T1C+', 'Carcinoma T2', 'Ependimoma T1', 'Ependimoma T1C+', 'Ependimoma T2', 'Ganglioglioma T1', 'Ganglioglioma T1C+', 'Ganglioglioma T2', 'Germinoma T1', 'Germinoma T1C+', 'Germinoma T2', 'Glioblastoma T1', 'Glioblastoma T1C+', 'Glioblastoma T2', 'Granuloma T1', 'Granuloma T1C+', 'Granuloma T2', 'Meduloblastoma T1', 'Meduloblastoma T1C+', 'Meduloblastoma T2', 'Meningioma T1', 'Meningioma T1C+', 'Meningioma T2', 'Neurocitoma T1', 'Neurocitoma T1C+', 'Neurocitoma T2', 'Oligodendroglioma T1', 'Oligodendroglioma T1C+', 'Oligodendroglioma T2', 'Papiloma T1', 'Papiloma T1C+', 'Papiloma T2', 'Schwannoma T1', 'Schwannoma T1C+', 'Schwannoma T2', 'Tuberculoma T1', 'Tuberculoma T1C+', 'Tuberculoma T2', '_NORMAL T1', '_NORMAL T2']
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)

# %%
preprocessing = keras.Sequential([
    keras.layers.Resizing(IMAGE_HEIGHT, IMAGE_WIDTH),
    keras.layers.Rescaling(1./255),
])

# %%
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(1),
    keras.layers.RandomTranslation(0.2, 0.2),
    keras.layers.RandomZoom(0.2),
    keras.layers.RandomBrightness(0.2),
    keras.layers.RandomContrast(0.2),
])

train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# <ParallelMapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = keras.models.Sequential([
    keras.layers.Input(shape=(None, None, INPUT_DIM)),

    preprocessing,

    keras.layers.Conv2D(32, 3, padding="same", activation="relu"),
    # keras.layers.BatchNormalization(momentum=0.87),
    keras.layers.MaxPooling2D(),

    keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    # keras.layers.BatchNormalization(momentum=0.87),
    keras.layers.MaxPooling2D(),
    
    keras.layers.Conv2D(128, 3, padding="same", activation="relu"),
    # keras.layers.BatchNormalization(momentum=0.87),
    keras.layers.MaxPooling2D(),

    # keras.layers.Conv2D(256, 3, padding="same", activation="relu"),
    # # keras.layers.BatchNormalization(momentum=0.87),
    # keras.layers.MaxPooling2D(),

    keras.layers.GlobalAveragePooling2D(),

    keras.layers.Dropout(0.4),

    keras.layers.Dense(NUM_CLASSES, activation="softmax")
])


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

model.summary(
    expand_nested=True,
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 64, 64, 3)         0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | resizing (Resizing)       (None, 64, 64, 3)         0         |
# |                                                               |
# | rescaling (Rescaling)     (None, 64, 64, 3)         0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 44)                5676
#
# =================================================================
# Total params: 98,924
# Trainable params: 98,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
earlystop_loss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[earlystop_loss],
)
# Out:
# Epoch 1/200
# 102/102 [==============================] - 8s 44ms/step - loss: 3.5353 - sparse_categorical_accuracy: 0.0740 - val_loss: 3.4809 - val_sparse_categorical_accuracy: 0.0728
# Epoch 2/200
# 102/102 [==============================] - 2s 18ms/step - loss: 3.4329 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.4221 - val_sparse_categorical_accuracy: 0.1049
# Epoch 3/200
# 102/102 [==============================] - 2s 18ms/step - loss: 3.3545 - sparse_categorical_accuracy: 0.1329 - val_loss: 3.3611 - val_sparse_categorical_accuracy: 0.1210
# Epoch 4/200
# 102/102 [==============================] - 2s 18ms/step - loss: 3.2852 - sparse_categorical_accuracy: 0.1455 - val_loss: 3.2793 - val_sparse_categorical_accuracy: 0.1617
# Epoch 5/200
# 102/102 [==============================] - 2s 18ms/step - loss: 3.1649 - sparse_categorical_accuracy: 0.1742 - val_loss: 3.1592 - val_sparse_categorical_accuracy: 0.1790
# Epoch 6/200
# 102/102 [==============================] - 2s 18ms/step - loss: 3.0383 - sparse_categorical_accuracy: 0.1983 - val_loss: 3.0669 - val_sparse_categorical_accuracy: 0.1840
# Epoch 7/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.9296 - sparse_categorical_accuracy: 0.2125 - val_loss: 2.9521 - val_sparse_categorical_accuracy: 0.2049
# Epoch 8/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.8330 - sparse_categorical_accuracy: 0.2350 - val_loss: 2.9527 - val_sparse_categorical_accuracy: 0.2123
# Epoch 9/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.7514 - sparse_categorical_accuracy: 0.2495 - val_loss: 2.7823 - val_sparse_categorical_accuracy: 0.2531
# Epoch 10/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.6573 - sparse_categorical_accuracy: 0.2667 - val_loss: 2.6779 - val_sparse_categorical_accuracy: 0.2765
# Epoch 11/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.5870 - sparse_categorical_accuracy: 0.2874 - val_loss: 2.6401 - val_sparse_categorical_accuracy: 0.2741
# Epoch 12/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.5035 - sparse_categorical_accuracy: 0.3151 - val_loss: 2.6034 - val_sparse_categorical_accuracy: 0.3049
# Epoch 13/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.4321 - sparse_categorical_accuracy: 0.3370 - val_loss: 2.4009 - val_sparse_categorical_accuracy: 0.3667
# Epoch 14/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.3601 - sparse_categorical_accuracy: 0.3509 - val_loss: 2.4321 - val_sparse_categorical_accuracy: 0.3593
# Epoch 15/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.2927 - sparse_categorical_accuracy: 0.3719 - val_loss: 2.3132 - val_sparse_categorical_accuracy: 0.3827
# Epoch 16/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.2063 - sparse_categorical_accuracy: 0.3827 - val_loss: 2.3371 - val_sparse_categorical_accuracy: 0.3753
# Epoch 17/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.1302 - sparse_categorical_accuracy: 0.4043 - val_loss: 2.1204 - val_sparse_categorical_accuracy: 0.4370
# Epoch 18/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.0912 - sparse_categorical_accuracy: 0.4117 - val_loss: 2.0758 - val_sparse_categorical_accuracy: 0.4407
# Epoch 19/200
# 102/102 [==============================] - 2s 18ms/step - loss: 2.0124 - sparse_categorical_accuracy: 0.4434 - val_loss: 1.9960 - val_sparse_categorical_accuracy: 0.4667
# Epoch 20/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.9884 - sparse_categorical_accuracy: 0.4372 - val_loss: 1.8960 - val_sparse_categorical_accuracy: 0.4741
# Epoch 21/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.9281 - sparse_categorical_accuracy: 0.4693 - val_loss: 1.8368 - val_sparse_categorical_accuracy: 0.5086
# Epoch 22/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.8683 - sparse_categorical_accuracy: 0.4758 - val_loss: 1.8056 - val_sparse_categorical_accuracy: 0.5222
# Epoch 23/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.8331 - sparse_categorical_accuracy: 0.4823 - val_loss: 1.7500 - val_sparse_categorical_accuracy: 0.5185
# Epoch 24/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.8125 - sparse_categorical_accuracy: 0.4986 - val_loss: 1.7186 - val_sparse_categorical_accuracy: 0.5407
# Epoch 25/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.7549 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.6642 - val_sparse_categorical_accuracy: 0.5407
# Epoch 26/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.7060 - sparse_categorical_accuracy: 0.5131 - val_loss: 1.6492 - val_sparse_categorical_accuracy: 0.5506
# Epoch 27/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.6615 - sparse_categorical_accuracy: 0.5251 - val_loss: 1.5965 - val_sparse_categorical_accuracy: 0.5642
# Epoch 28/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.6384 - sparse_categorical_accuracy: 0.5233 - val_loss: 1.5749 - val_sparse_categorical_accuracy: 0.5691
# Epoch 29/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.6209 - sparse_categorical_accuracy: 0.5353 - val_loss: 1.5326 - val_sparse_categorical_accuracy: 0.5840
# Epoch 30/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.5344 - val_loss: 1.5484 - val_sparse_categorical_accuracy: 0.5914
# Epoch 31/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.5591 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.4781 - val_sparse_categorical_accuracy: 0.5901
# Epoch 32/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.5060 - sparse_categorical_accuracy: 0.5677 - val_loss: 1.4521 - val_sparse_categorical_accuracy: 0.5938
# Epoch 33/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.4905 - sparse_categorical_accuracy: 0.5686 - val_loss: 1.4210 - val_sparse_categorical_accuracy: 0.5988
# Epoch 34/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.4659 - sparse_categorical_accuracy: 0.5760 - val_loss: 1.3881 - val_sparse_categorical_accuracy: 0.6086
# Epoch 35/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.4277 - sparse_categorical_accuracy: 0.5840 - val_loss: 1.3700 - val_sparse_categorical_accuracy: 0.6198
# Epoch 36/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.4255 - sparse_categorical_accuracy: 0.5893 - val_loss: 1.3513 - val_sparse_categorical_accuracy: 0.6235
# Epoch 37/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.3998 - sparse_categorical_accuracy: 0.5948 - val_loss: 1.3131 - val_sparse_categorical_accuracy: 0.6259
# Epoch 38/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.3735 - sparse_categorical_accuracy: 0.6041 - val_loss: 1.3630 - val_sparse_categorical_accuracy: 0.6210
# Epoch 39/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.3533 - sparse_categorical_accuracy: 0.5976 - val_loss: 1.2767 - val_sparse_categorical_accuracy: 0.6309
# Epoch 40/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.3237 - sparse_categorical_accuracy: 0.6207 - val_loss: 1.2689 - val_sparse_categorical_accuracy: 0.6395
# Epoch 41/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.2755 - sparse_categorical_accuracy: 0.6263 - val_loss: 1.2139 - val_sparse_categorical_accuracy: 0.6444
# Epoch 42/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.2824 - sparse_categorical_accuracy: 0.6281 - val_loss: 1.2659 - val_sparse_categorical_accuracy: 0.6407
# Epoch 43/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.2839 - sparse_categorical_accuracy: 0.6192 - val_loss: 1.1932 - val_sparse_categorical_accuracy: 0.6543
# Epoch 44/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.2252 - sparse_categorical_accuracy: 0.6438 - val_loss: 1.1945 - val_sparse_categorical_accuracy: 0.6469
# Epoch 45/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.2165 - sparse_categorical_accuracy: 0.6324 - val_loss: 1.1476 - val_sparse_categorical_accuracy: 0.6716
# Epoch 46/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.2024 - sparse_categorical_accuracy: 0.6401 - val_loss: 1.1313 - val_sparse_categorical_accuracy: 0.6654
# Epoch 47/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.1464 - sparse_categorical_accuracy: 0.6608 - val_loss: 1.1584 - val_sparse_categorical_accuracy: 0.6667
# Epoch 48/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.1752 - sparse_categorical_accuracy: 0.6423 - val_loss: 1.1026 - val_sparse_categorical_accuracy: 0.6741
# Epoch 49/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.1372 - sparse_categorical_accuracy: 0.6605 - val_loss: 1.0901 - val_sparse_categorical_accuracy: 0.6790
# Epoch 50/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.1355 - sparse_categorical_accuracy: 0.6574 - val_loss: 1.0780 - val_sparse_categorical_accuracy: 0.6741
# Epoch 51/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.0883 - sparse_categorical_accuracy: 0.6781 - val_loss: 1.0636 - val_sparse_categorical_accuracy: 0.6840
# Epoch 52/200
# 102/102 [==============================] - 2s 17ms/step - loss: 1.0828 - sparse_categorical_accuracy: 0.6765 - val_loss: 1.1288 - val_sparse_categorical_accuracy: 0.6642
# Epoch 53/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.0682 - sparse_categorical_accuracy: 0.6747 - val_loss: 1.0223 - val_sparse_categorical_accuracy: 0.7136
# Epoch 54/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.0677 - sparse_categorical_accuracy: 0.6784 - val_loss: 1.0367 - val_sparse_categorical_accuracy: 0.6975
# Epoch 55/200
# 102/102 [==============================] - 2s 19ms/step - loss: 1.0356 - sparse_categorical_accuracy: 0.6879 - val_loss: 1.0036 - val_sparse_categorical_accuracy: 0.7037
# Epoch 56/200
# 102/102 [==============================] - 2s 19ms/step - loss: 1.0396 - sparse_categorical_accuracy: 0.6870 - val_loss: 0.9947 - val_sparse_categorical_accuracy: 0.7198
# Epoch 57/200
# 102/102 [==============================] - 2s 18ms/step - loss: 1.0179 - sparse_categorical_accuracy: 0.6957 - val_loss: 1.0180 - val_sparse_categorical_accuracy: 0.7000
# Epoch 58/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9866 - sparse_categorical_accuracy: 0.7037 - val_loss: 0.9561 - val_sparse_categorical_accuracy: 0.7185
# Epoch 59/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9745 - sparse_categorical_accuracy: 0.7052 - val_loss: 0.9598 - val_sparse_categorical_accuracy: 0.7247
# Epoch 60/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9673 - sparse_categorical_accuracy: 0.7027 - val_loss: 0.9458 - val_sparse_categorical_accuracy: 0.7296
# Epoch 61/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9310 - sparse_categorical_accuracy: 0.7225 - val_loss: 0.9350 - val_sparse_categorical_accuracy: 0.7469
# Epoch 62/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9369 - sparse_categorical_accuracy: 0.7086 - val_loss: 0.9394 - val_sparse_categorical_accuracy: 0.7235
# Epoch 63/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9262 - sparse_categorical_accuracy: 0.7206 - val_loss: 0.9436 - val_sparse_categorical_accuracy: 0.7198
# Epoch 64/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9135 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.9105 - val_sparse_categorical_accuracy: 0.7383
# Epoch 65/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.8886 - sparse_categorical_accuracy: 0.7286 - val_loss: 0.8883 - val_sparse_categorical_accuracy: 0.7358
# Epoch 66/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.9056 - sparse_categorical_accuracy: 0.7182 - val_loss: 0.8981 - val_sparse_categorical_accuracy: 0.7346
# Epoch 67/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.8973 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.8843 - val_sparse_categorical_accuracy: 0.7432
# Epoch 68/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.8628 - sparse_categorical_accuracy: 0.7397 - val_loss: 0.8890 - val_sparse_categorical_accuracy: 0.7481
# Epoch 69/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.8593 - sparse_categorical_accuracy: 0.7351 - val_loss: 0.8581 - val_sparse_categorical_accuracy: 0.7494
# Epoch 70/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.8191 - sparse_categorical_accuracy: 0.7428 - val_loss: 0.8448 - val_sparse_categorical_accuracy: 0.7543
# Epoch 71/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.8155 - sparse_categorical_accuracy: 0.7459 - val_loss: 0.8462 - val_sparse_categorical_accuracy: 0.7556
# Epoch 72/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.8364 - sparse_categorical_accuracy: 0.7342 - val_loss: 0.8362 - val_sparse_categorical_accuracy: 0.7630
# Epoch 73/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.7824 - sparse_categorical_accuracy: 0.7638 - val_loss: 0.8330 - val_sparse_categorical_accuracy: 0.7630
# Epoch 74/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.8268 - sparse_categorical_accuracy: 0.7407 - val_loss: 0.8375 - val_sparse_categorical_accuracy: 0.7617
# Epoch 75/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.7791 - sparse_categorical_accuracy: 0.7607 - val_loss: 0.8281 - val_sparse_categorical_accuracy: 0.7593
# Epoch 76/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.7725 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.8030 - val_sparse_categorical_accuracy: 0.7654
# Epoch 77/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.7757 - sparse_categorical_accuracy: 0.7549 - val_loss: 0.8287 - val_sparse_categorical_accuracy: 0.7556
# Epoch 78/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.7600 - sparse_categorical_accuracy: 0.7644 - val_loss: 0.8194 - val_sparse_categorical_accuracy: 0.7543
# Epoch 79/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.7431 - sparse_categorical_accuracy: 0.7734 - val_loss: 0.7973 - val_sparse_categorical_accuracy: 0.7580
# Epoch 80/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.7432 - sparse_categorical_accuracy: 0.7706 - val_loss: 0.7678 - val_sparse_categorical_accuracy: 0.7790
# Epoch 81/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.7342 - sparse_categorical_accuracy: 0.7666 - val_loss: 0.8042 - val_sparse_categorical_accuracy: 0.7679
# Epoch 82/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.7140 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.7464 - val_sparse_categorical_accuracy: 0.7778
# Epoch 83/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6846 - sparse_categorical_accuracy: 0.7838 - val_loss: 0.7315 - val_sparse_categorical_accuracy: 0.7815
# Epoch 84/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6704 - sparse_categorical_accuracy: 0.7860 - val_loss: 0.7413 - val_sparse_categorical_accuracy: 0.7864
# Epoch 85/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6754 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.7356 - val_sparse_categorical_accuracy: 0.7827
# Epoch 86/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6862 - sparse_categorical_accuracy: 0.7814 - val_loss: 0.7373 - val_sparse_categorical_accuracy: 0.7815
# Epoch 87/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6436 - sparse_categorical_accuracy: 0.7971 - val_loss: 0.7994 - val_sparse_categorical_accuracy: 0.7642
# Epoch 88/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6569 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.7334 - val_sparse_categorical_accuracy: 0.7864
# Epoch 89/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6399 - sparse_categorical_accuracy: 0.7965 - val_loss: 0.7324 - val_sparse_categorical_accuracy: 0.7852
# Epoch 90/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6308 - sparse_categorical_accuracy: 0.8017 - val_loss: 0.7252 - val_sparse_categorical_accuracy: 0.7938
# Epoch 91/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.6364 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.7286 - val_sparse_categorical_accuracy: 0.7679
# Epoch 92/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.6250 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.7134 - val_sparse_categorical_accuracy: 0.7852
# Epoch 93/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6279 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.6868 - val_sparse_categorical_accuracy: 0.7926
# Epoch 94/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6220 - sparse_categorical_accuracy: 0.8030 - val_loss: 0.6830 - val_sparse_categorical_accuracy: 0.8062
# Epoch 95/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.6953 - val_sparse_categorical_accuracy: 0.8025
# Epoch 96/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5694 - sparse_categorical_accuracy: 0.8159 - val_loss: 0.7080 - val_sparse_categorical_accuracy: 0.7926
# Epoch 97/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5867 - sparse_categorical_accuracy: 0.8181 - val_loss: 0.7564 - val_sparse_categorical_accuracy: 0.7889
# Epoch 98/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.5730 - sparse_categorical_accuracy: 0.8162 - val_loss: 0.6850 - val_sparse_categorical_accuracy: 0.8049
# Epoch 99/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.5542 - sparse_categorical_accuracy: 0.8205 - val_loss: 0.6902 - val_sparse_categorical_accuracy: 0.7988
# Epoch 100/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.6784 - val_sparse_categorical_accuracy: 0.8025
# Epoch 101/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.5307 - sparse_categorical_accuracy: 0.8384 - val_loss: 0.6668 - val_sparse_categorical_accuracy: 0.8160
# Epoch 102/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5584 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.7171 - val_sparse_categorical_accuracy: 0.7926
# Epoch 103/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5267 - sparse_categorical_accuracy: 0.8316 - val_loss: 0.6791 - val_sparse_categorical_accuracy: 0.8136
# Epoch 104/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5620 - sparse_categorical_accuracy: 0.8252 - val_loss: 0.6566 - val_sparse_categorical_accuracy: 0.8148
# Epoch 105/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5222 - sparse_categorical_accuracy: 0.8369 - val_loss: 0.6623 - val_sparse_categorical_accuracy: 0.8148
# Epoch 106/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5077 - sparse_categorical_accuracy: 0.8329 - val_loss: 0.6613 - val_sparse_categorical_accuracy: 0.8173
# Epoch 107/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5089 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.6758 - val_sparse_categorical_accuracy: 0.8086
# Epoch 108/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4886 - sparse_categorical_accuracy: 0.8393 - val_loss: 0.6996 - val_sparse_categorical_accuracy: 0.8000
# Epoch 109/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4944 - sparse_categorical_accuracy: 0.8341 - val_loss: 0.6670 - val_sparse_categorical_accuracy: 0.8136
# Epoch 110/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.5086 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.6898 - val_sparse_categorical_accuracy: 0.8037
# Epoch 111/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4795 - sparse_categorical_accuracy: 0.8486 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.8049
# Epoch 112/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4881 - sparse_categorical_accuracy: 0.8418 - val_loss: 0.6453 - val_sparse_categorical_accuracy: 0.8136
# Epoch 113/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4672 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.8148
# Epoch 114/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4341 - sparse_categorical_accuracy: 0.8557 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.8062
# Epoch 115/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4489 - sparse_categorical_accuracy: 0.8557 - val_loss: 0.6853 - val_sparse_categorical_accuracy: 0.8086
# Epoch 116/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4541 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.6181 - val_sparse_categorical_accuracy: 0.8222
# Epoch 117/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4451 - sparse_categorical_accuracy: 0.8523 - val_loss: 0.6573 - val_sparse_categorical_accuracy: 0.8099
# Epoch 118/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4240 - sparse_categorical_accuracy: 0.8566 - val_loss: 0.6306 - val_sparse_categorical_accuracy: 0.8210
# Epoch 119/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4334 - sparse_categorical_accuracy: 0.8603 - val_loss: 0.6118 - val_sparse_categorical_accuracy: 0.8222
# Epoch 120/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4001 - sparse_categorical_accuracy: 0.8776 - val_loss: 0.6173 - val_sparse_categorical_accuracy: 0.8383
# Epoch 121/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4126 - sparse_categorical_accuracy: 0.8677 - val_loss: 0.6865 - val_sparse_categorical_accuracy: 0.8049
# Epoch 122/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4120 - sparse_categorical_accuracy: 0.8606 - val_loss: 0.6646 - val_sparse_categorical_accuracy: 0.8062
# Epoch 123/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4232 - sparse_categorical_accuracy: 0.8671 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.8099
# Epoch 124/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.4065 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.6315 - val_sparse_categorical_accuracy: 0.8222
# Epoch 125/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4008 - sparse_categorical_accuracy: 0.8702 - val_loss: 0.5965 - val_sparse_categorical_accuracy: 0.8370
# Epoch 126/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.4131 - sparse_categorical_accuracy: 0.8736 - val_loss: 0.7432 - val_sparse_categorical_accuracy: 0.7975
# Epoch 127/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.3969 - sparse_categorical_accuracy: 0.8686 - val_loss: 0.5890 - val_sparse_categorical_accuracy: 0.8321
# Epoch 128/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3840 - sparse_categorical_accuracy: 0.8730 - val_loss: 0.5957 - val_sparse_categorical_accuracy: 0.8284
# Epoch 129/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3832 - sparse_categorical_accuracy: 0.8711 - val_loss: 0.6123 - val_sparse_categorical_accuracy: 0.8198
# Epoch 130/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3758 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.6217 - val_sparse_categorical_accuracy: 0.8247
# Epoch 131/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3641 - sparse_categorical_accuracy: 0.8825 - val_loss: 0.5978 - val_sparse_categorical_accuracy: 0.8333
# Epoch 132/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3619 - sparse_categorical_accuracy: 0.8853 - val_loss: 0.6229 - val_sparse_categorical_accuracy: 0.8346
# Epoch 133/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.8871 - val_loss: 0.5971 - val_sparse_categorical_accuracy: 0.8296
# Epoch 134/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3608 - sparse_categorical_accuracy: 0.8871 - val_loss: 0.6158 - val_sparse_categorical_accuracy: 0.8284
# Epoch 135/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3507 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.6529 - val_sparse_categorical_accuracy: 0.8309
# Epoch 136/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3436 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.6258 - val_sparse_categorical_accuracy: 0.8198
# Epoch 137/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.8813 - val_loss: 0.5540 - val_sparse_categorical_accuracy: 0.8432
# Epoch 138/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3516 - sparse_categorical_accuracy: 0.8862 - val_loss: 0.5841 - val_sparse_categorical_accuracy: 0.8358
# Epoch 139/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.8979 - val_loss: 0.5991 - val_sparse_categorical_accuracy: 0.8383
# Epoch 140/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3246 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.5720 - val_sparse_categorical_accuracy: 0.8395
# Epoch 141/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3366 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.5529 - val_sparse_categorical_accuracy: 0.8407
# Epoch 142/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3333 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.5985 - val_sparse_categorical_accuracy: 0.8444
# Epoch 143/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3358 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.5562 - val_sparse_categorical_accuracy: 0.8481
# Epoch 144/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3015 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.5877 - val_sparse_categorical_accuracy: 0.8383
# Epoch 145/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3301 - sparse_categorical_accuracy: 0.8933 - val_loss: 0.6129 - val_sparse_categorical_accuracy: 0.8296
# Epoch 146/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3302 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.5514 - val_sparse_categorical_accuracy: 0.8420
# Epoch 147/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.5794 - val_sparse_categorical_accuracy: 0.8407
# Epoch 148/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3068 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.5557 - val_sparse_categorical_accuracy: 0.8420
# Epoch 149/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.3195 - sparse_categorical_accuracy: 0.8998 - val_loss: 0.6651 - val_sparse_categorical_accuracy: 0.8185
# Epoch 150/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2935 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.5513 - val_sparse_categorical_accuracy: 0.8358
# Epoch 151/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2950 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.5960 - val_sparse_categorical_accuracy: 0.8358
# Epoch 152/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2915 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.5332 - val_sparse_categorical_accuracy: 0.8543
# Epoch 153/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2864 - sparse_categorical_accuracy: 0.9115 - val_loss: 0.5580 - val_sparse_categorical_accuracy: 0.8543
# Epoch 154/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2888 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.8420
# Epoch 155/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2805 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.6148 - val_sparse_categorical_accuracy: 0.8395
# Epoch 156/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.6084 - val_sparse_categorical_accuracy: 0.8346
# Epoch 157/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2888 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.5773 - val_sparse_categorical_accuracy: 0.8506
# Epoch 158/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.5139 - val_sparse_categorical_accuracy: 0.8654
# Epoch 159/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.5584 - val_sparse_categorical_accuracy: 0.8432
# Epoch 160/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2520 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.8395
# Epoch 161/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2758 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.5237 - val_sparse_categorical_accuracy: 0.8617
# Epoch 162/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2495 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.5171 - val_sparse_categorical_accuracy: 0.8494
# Epoch 163/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.5534 - val_sparse_categorical_accuracy: 0.8506
# Epoch 164/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2358 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.5861 - val_sparse_categorical_accuracy: 0.8506
# Epoch 165/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2486 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.5252 - val_sparse_categorical_accuracy: 0.8617
# Epoch 166/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2566 - sparse_categorical_accuracy: 0.9109 - val_loss: 0.5061 - val_sparse_categorical_accuracy: 0.8556
# Epoch 167/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2564 - sparse_categorical_accuracy: 0.9121 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.8469
# Epoch 168/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2438 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.5622 - val_sparse_categorical_accuracy: 0.8481
# Epoch 169/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2327 - sparse_categorical_accuracy: 0.9232 - val_loss: 0.5371 - val_sparse_categorical_accuracy: 0.8556
# Epoch 170/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.2361 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.4980 - val_sparse_categorical_accuracy: 0.8630
# Epoch 171/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2301 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.5376 - val_sparse_categorical_accuracy: 0.8494
# Epoch 172/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9285 - val_loss: 0.4942 - val_sparse_categorical_accuracy: 0.8519
# Epoch 173/200
# 102/102 [==============================] - 2s 17ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9257 - val_loss: 0.5426 - val_sparse_categorical_accuracy: 0.8469
# Epoch 174/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2365 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.5464 - val_sparse_categorical_accuracy: 0.8543
# Epoch 175/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2080 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.5389 - val_sparse_categorical_accuracy: 0.8556
# Epoch 176/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2285 - sparse_categorical_accuracy: 0.9235 - val_loss: 0.5588 - val_sparse_categorical_accuracy: 0.8494
# Epoch 177/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2141 - sparse_categorical_accuracy: 0.9322 - val_loss: 0.5573 - val_sparse_categorical_accuracy: 0.8420
# Epoch 178/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.2159 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.5572 - val_sparse_categorical_accuracy: 0.8556
# Epoch 179/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.2165 - sparse_categorical_accuracy: 0.9331 - val_loss: 0.4963 - val_sparse_categorical_accuracy: 0.8543
# Epoch 180/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2119 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.5669 - val_sparse_categorical_accuracy: 0.8420
# Epoch 181/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.2084 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.5109 - val_sparse_categorical_accuracy: 0.8765
# Epoch 182/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1899 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.5027 - val_sparse_categorical_accuracy: 0.8654
# Epoch 183/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2090 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.5724 - val_sparse_categorical_accuracy: 0.8457
# Epoch 184/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2058 - sparse_categorical_accuracy: 0.9285 - val_loss: 0.5160 - val_sparse_categorical_accuracy: 0.8630
# Epoch 185/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2036 - sparse_categorical_accuracy: 0.9315 - val_loss: 0.5005 - val_sparse_categorical_accuracy: 0.8654
# Epoch 186/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.1873 - sparse_categorical_accuracy: 0.9396 - val_loss: 0.5243 - val_sparse_categorical_accuracy: 0.8691
# Epoch 187/200
# 102/102 [==============================] - 2s 19ms/step - loss: 0.1913 - sparse_categorical_accuracy: 0.9399 - val_loss: 0.5679 - val_sparse_categorical_accuracy: 0.8494
# Epoch 188/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1863 - sparse_categorical_accuracy: 0.9408 - val_loss: 0.5553 - val_sparse_categorical_accuracy: 0.8654
# Epoch 189/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1863 - sparse_categorical_accuracy: 0.9386 - val_loss: 0.5593 - val_sparse_categorical_accuracy: 0.8753
# Epoch 190/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1972 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.5618 - val_sparse_categorical_accuracy: 0.8543
# Epoch 191/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1774 - sparse_categorical_accuracy: 0.9463 - val_loss: 0.5582 - val_sparse_categorical_accuracy: 0.8556
# Epoch 192/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1864 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.5390 - val_sparse_categorical_accuracy: 0.8580
# Epoch 193/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9315 - val_loss: 0.5399 - val_sparse_categorical_accuracy: 0.8580
# Epoch 194/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1816 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.5178 - val_sparse_categorical_accuracy: 0.8679
# Epoch 195/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1843 - sparse_categorical_accuracy: 0.9399 - val_loss: 0.5554 - val_sparse_categorical_accuracy: 0.8617
# Epoch 196/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1778 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.5237 - val_sparse_categorical_accuracy: 0.8704
# Epoch 197/200
# 102/102 [==============================] - 2s 18ms/step - loss: 0.1792 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.5499 - val_sparse_categorical_accuracy: 0.8691

# %%
from matplotlib import pyplot as plt

print("Epochs run:", len(history.history["loss"]))

acc = history.history["sparse_categorical_accuracy"]
val_acc = history.history["val_sparse_categorical_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.ylim((0, 1))
plt.plot(epochs, acc, label="Training accurarcy")
plt.plot(epochs, val_acc, label="Validation accurarcy")
plt.title("Training and Validation accurarcy")
plt.legend()

# Train and validation loss
plt.subplot(1, 2, 2)

plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.title("Training and Validation loss")
plt.legend()
plt.show()
# Out:
# Epochs run: 197

# %%
test_ds = keras.utils.image_dataset_from_directory(F"{DATASET_DIR}/test",color_mode=COLOR_MODE,)

results = model.evaluate(test_ds, verbose=0)

print("Test accuracy:", results[1]*100)
print("Test loss:", results[0]*100)
# Out:
# Found 425 files belonging to 44 classes.
# Test accuracy: 68.70588064193726
# Test loss: 148.2667326927185

# %%
dot_img_file = '/tmp/model_architecture.png'
tf.keras.utils.plot_model(
    model,
    to_file=dot_img_file,
    show_shapes=True,
    show_layer_names=False,
    expand_nested=True
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.save('./SavedModels/model_44C')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./SavedModels/model_44C\assets
# INFO:tensorflow:Assets written to: ./SavedModels/model_44C\assets
